# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the CSV (make sure the CSV is in the same folder as your notebook or give full path)
df = pd.read_csv("bike_trip_data_500.csv")
df.head()
# Out:
#    Distance (km)  Duration (min)  Travel Way  Mileage (km/l)
# 0          20.99           54.75         1.0           42.52
# 1          22.82           48.90         1.0           42.23
# 2           5.37            4.81         0.0           46.41
# 3           5.39            3.99         0.0           47.79
# 4           6.40            5.57         0.0           48.81

# %%
# Features and target
X = df[['Distance (km)', 'Duration (min)', 'Travel Way']]
y = df['Mileage (km/l)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

y_pred = model.predict(X_test)

# Evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("Mean Squared Error:", round(mse, 2))
print("Mean Absolute Error:", round(mae, 2))
print("R² Score:", round(r2, 2))
# Out:
# Mean Squared Error: 1.35
# Mean Absolute Error: 0.92
# R² Score: 0.85

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Mileage")
plt.ylabel("Predicted Mileage")
plt.title("Actual vs Predicted Mileage")
plt.grid(True)
plt.show()
